# %%
import sys
import pandas as pd

# BERT
from sentence_transformers import SentenceTransformer
import scipy.spatial

# %%
QUESTIONS_CSV = "questions.csv"
COMMENTS_CSV = "comments.csv"
BEST_ANSWERS_CSV = "best-answers.csv"

# %% [markdown]
# ### Explore data

# %%
# Read questions
q_df = pd.read_csv(QUESTIONS_CSV,index_col=[0])
q_df.info()
q_df.head(3)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 881 entries, 0 to 880
# Data columns (total 9 columns):
# date           881 non-null object
# id             881 non-null int64
# author_name    881 non-null object
# title          881 non-null object
# hash_tags      440 non-null object
# description    881 non-null object
# file           881 non-null object
# url            881 non-null object
# wifi_tv        881 non-null bool
# dtypes: bool(1), int64(1), object(7)
# memory usage: 62.8+ KB
#                   date     id  author_name  \
# 0  2020-01-20 17:11:57  11804    ajfromftf
# 1  2018-09-25 11:20:47   2069      Pamoola
# 2  2018-11-11 16:38:32   2475  waltstanley
#
#                                                title  \
# 0  65UM6900PUA won’t stay connected to WiFi when ...
# 1  Smart LED TV Model: 43UH6100 IS connected to W...
# 2                                           65UH5500
#
#                     hash_tags  \
# 0     tv connect network wifi
# 1  wifi internet home network
# 2                         NaN
#
#                                          description  \
# 0  \n                    Every time I turn off my...
# 1  \n                    This happens on a daily ...
# 2  \n                    No TV viewers, any reply...
#
#                                                 file  \
# 0  11804-65um6900pua-won-t-stay-connected-to-wifi...
# 1  2069-smart-led-tv-model-43uh6100-is-connected-...
# 2                                      2475-65uh5500
#
#                                                  url  wifi_tv
# 0  https://lgcommunity.us.com/discussion/11804/65...     True
# 1  https://lgcommunity.us.com/discussion/2069/sma...     True
# 2  https://lgcommunity.us.com/discussion/2475/65u...    False

# %%
# Read comments
c_df = pd.read_csv(COMMENTS_CSV, index_col=[0])
c_df.info()
c_df.head(3)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1849 entries, 0 to 1848
# Data columns (total 10 columns):
# date               1849 non-null object
# question_id        1849 non-null int64
# hash_tags          942 non-null object
# comment_id         1849 non-null int64
# username           1849 non-null object
# message            1849 non-null object
# helpful_cnt        1849 non-null int64
# not_helpful_cnt    1849 non-null int64
# rating             1849 non-null int64
# file               1849 non-null object
# dtypes: int64(5), object(5)
# memory usage: 158.9+ KB
#                   date  question_id                   hash_tags  comment_id  \
# 0  2020-01-21 14:11:21        11804     tv connect network wifi       18595
# 1  2018-11-28 17:24:19         2069  wifi internet home network        4162
# 2  2018-11-29 05:32:06         2069  wifi internet home network        4222
#
#   username                                            message  helpful_cnt  \
# 0   big80s  \n                            We bought two ne...            0
# 1  AhmedLG  \n                            Hello @Pamoola I...            0
# 2   Lpops6  \n                            When I go to the...            0
#
#    not_helpful_cnt  rating                                               file
# 0                0       0  11804-65um6900pua-won-t-stay-connected-to-wifi...
# 1                0       0  2069-smart-led-tv-model-43uh6100-is-connected-...
# 2                0       0  2069-smart-led-tv-model-43uh6100-is-connected-...

# %%
# Helpful answers
c_df['helpful_cnt'].value_counts()
# Out:
# 0    1683
# 1     133
# 2      23
# 3       8
# 4       2
# Name: helpful_cnt, dtype: int64

# %%
max_helpful_comments = c_df.loc[c_df['helpful_cnt'] == 4]
max_helpful_comments
# Out:
#                      date  question_id                         hash_tags  \
# 1366  2018-12-14 16:23:36         1621  tv 4k UHD 4k smrt tv someonehelp
# 1814  2018-09-04 02:09:31         1106                               NaN
#
#       comment_id  username                                            message  \
# 1366        4619  tboudrot  \n                            This issue is we...
# 1814        2458  patrickg  \n                            Same here my 65u...
#
#       helpful_cnt  not_helpful_cnt  rating  \
# 1366            4                0       4
# 1814            4                0       4
#
#                                         file
# 1366  1621-annoying-message-pops-up-on-my-tv
# 1814          1106-65uh5500-will-not-turn-on

# %%
max_helpful_comments['file']
# Out:
# 1366    1621-annoying-message-pops-up-on-my-tv
# 1814            1106-65uh5500-will-not-turn-on
# Name: file, dtype: object

# %%
max_helpful_comments['message'].values
# Out:
# array(["\n                            This issue is well documented on various Internet sites.\xa0 The issue -- unknown device is disconnected -- along with flaky remote controller behavior and the TV's inability to recognize wireless networks are all related and experienced by many people.\xa0 I called LG tech support two weeks ago and the service agent claimed no awareness of the issue.\xa0 Very disappointing since many people have reported it to LG tech support and only a few have been able to resolve it through warranty channels.\xa0 The older the TV, the less likelihood you'll have in getting warranty service.The issue appears to be related to the wifi board in the TV itself.\xa0 Some individuals experiencing the issue have had that board replaced and a few report success while others do not.\xa0 Since I use the wifi capability of the TV to watch Netflix and Amazon Prime, the TV is now useless to me as it can't access the wireless network.\xa0\xa0                        ",
#        '\n                            Same here my 65uh5500 just went out. If i unplug it and plug it back in the logo will flash for just a second and the red standby light will come on then flash 2 or three times. Mine\xa0 was manufactured in june 2016 and purchased in october 2016 not even a full two years. Im begining to wonder if its an update issue.                        '],
#       dtype=object)

# %%
# Not helpful answers
c_df['not_helpful_cnt'].value_counts()
# Out:
# 0    1763
# 1      72
# 2      12
# 9       1
# 3       1
# Name: not_helpful_cnt, dtype: int64

# %%
max_not_helpful_comments = c_df.loc[c_df['not_helpful_cnt'] == 9]
max_not_helpful_comments
# Out:
#                      date  question_id                         hash_tags  \
# 1360  2018-08-31 20:36:39         1621  tv 4k UHD 4k smrt tv someonehelp
#
#       comment_id   username  \
# 1360        2390  Alexander
#
#                                                 message  helpful_cnt  \
# 1360  \n@Bernie110, Good day,Have you identified wha...            0
#
#       not_helpful_cnt  rating                                    file
# 1360                9      -9  1621-annoying-message-pops-up-on-my-tv

# %%
max_not_helpful_comments['file']
# Out:
# 1360    1621-annoying-message-pops-up-on-my-tv
# Name: file, dtype: object

# %%
max_not_helpful_comments['message'].values
# Out:
# array(['\n@Bernie110, Good day,Have you identified what connection is causing this error? do you have multiple electronics connected to your TV? If so, try using it with one of them disconnected and every 15 minutes rotate the product that is disconnected. Once identified, ensure its properly connected, try using different ports and / or cables to confirm if its the TV port, the cable or the product its connected to.If the above does not solve the issue, you can try a factory reset.If that still does not fix the issue please let us know your model number and the software version you are currently running so it can be escalated.                        '],
#       dtype=object)

# %%
# Answer ratings
c_df['rating'].value_counts()
# Out:
#  0    1612
#  1     128
# -1      65
#  2      21
# -2      11
#  3       8
#  4       2
# -3       1
# -9       1
# Name: rating, dtype: int64

# %% [markdown]
# ### Question 1.
# - 1.1. Which were the first ten threads of 2019?
# - 1.2. Which of these threads could be considered questions?
# - 1.3. Which received answers?
# - 1.4. For each answer, what is your gut judgement for how likely the answer would have been accepted by
# the thread starter? Why?

# %% [markdown]
# #### Answers 1.1, 1.2

# %%
# q19_df - threads with all questions in 2019
mask = (q_df['date'] > '2018-12-31') & (q_df['date'] <= '2019-12-31')
q19_df = q_df.loc[mask].copy()
q19_df.info()
q19_df.head(3)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 466 entries, 4 to 873
# Data columns (total 9 columns):
# date           466 non-null object
# id             466 non-null int64
# author_name    466 non-null object
# title          466 non-null object
# hash_tags      245 non-null object
# description    466 non-null object
# file           466 non-null object
# url            466 non-null object
# wifi_tv        466 non-null bool
# dtypes: bool(1), int64(1), object(7)
# memory usage: 33.2+ KB
#                   date    id  author_name  \
# 4  2019-08-19 21:00:57  5745     jmcl1960
# 5  2019-02-01 13:29:16  3483  johnnybiral
# 8  2019-12-07 03:32:31  8599   PickyBiker
#
#                                                title  \
# 4  LG 55UK6200PUA Sound Mode is "Deactivated, can...
# 5                 Some keys on my remote dosent work
# 8  ULTRA HD Deep Color mode blanks out the ROKU P...
#
#                      hash_tags  \
# 4                          NaN
# 5  Magic Remote Remote Control
# 8                          NaN
#
#                                          description  \
# 4  \nMy LG 55UK6200PUA Sound Mode is "Deactivated...
# 5  \n                    TV Model: 43UF64000GIRem...
# 8  \nThere is a problem with this TV and the ROKU...
#
#                                                 file  \
# 4  5745-lg-55uk6200pua-sound-mode-is-deactivated-...
# 5            3483-some-keys-on-my-remote-dosent-work
# 8  8599-ultra-hd-deep-color-mode-blanks-out-the-r...
#
#                                                  url  wifi_tv
# 4  https://lgcommunity.us.com/discussion/5745/lg-...    False
# 5  https://lgcommunity.us.com/discussion/3483/som...    False
# 8  https://lgcommunity.us.com/discussion/8599/ult...    False

# %%
# q19_df_10 - is a data frame with first ten threads of 2019 that could be considered questions
# (Threads without questions were filtered out at previous data extraction step in
# (extract-data.ipynb))

q19_df_sorted = q19_df.sort_values(by='date').copy()
q19_df_10 = q19_df_sorted.head(10)
q19_df_10.head(3)
# Out:
#                     date    id author_name  \
# 326  2019-01-01 22:24:24  3132    dougfern
# 256  2019-01-02 19:47:27  3144    joanne01
# 724  2019-01-03 07:38:20  3155   ericsang1
#
#                                                title hash_tags  \
# 326  Re-pairing TV/Bluetooth soundbar after shutdown       NaN
# 256                          Blurry picture and text       NaN
# 724                   Unknown Device Is Disconnected       NaN
#
#                                            description  \
# 326  \nMy new LG 50UK6500AUA TV and SK1 soundbar pa...
# 256  \n                    just set up  60inch 60UK...
# 724  \n                    I bought my UJ6300 tv ab...
#
#                                                   file  \
# 326  3132-re-pairing-tv-bluetooth-soundbar-after-sh...
# 256                       3144-blurry-picture-and-text
# 724                3155-unknown-device-is-disconnected
#
#                                                    url  wifi_tv
# 326  https://lgcommunity.us.com/discussion/3132/re-...    False
# 256  https://lgcommunity.us.com/discussion/3144/blu...    False
# 724  https://lgcommunity.us.com/discussion/3155/unk...    False

# %% [markdown]
# #### Answer 1.3
#  - 1.3. Which received answers?

# %% [markdown]
# #### To answer 1.3:
# - We join 10 questions with comments using id of the question in both data frames

# %%
def join(q_df, c_df):
    """ Join question and comments dataframes
    
        Args:
            q - question dataframe 
            c - comments dataframe
            
        Returns:
            Left join product with duplicated columns droped and 'x-names' renamed
 
    """  
    df = pd.merge(q_df, c_df, left_on='id', right_on='question_id', how='left')
    drop_cols = ['date_y', 'question_id', 'hash_tags_y', 'file_y' ]
    df = df.drop(drop_cols, axis=1)
    df.rename(columns = {'file_x':'file', 'date_x':'date', 'hash_tags_x': 'hash_tags'}, 
              inplace = True)
    return df

# %% [markdown]
# #### First ten threads of 2019 with answers

# %%
qc10_df = join(q19_df_10, c_df).copy()
qc10_df.info()
qc10_df.head(3)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16 entries, 0 to 15
# Data columns (total 15 columns):
# date               16 non-null object
# id                 16 non-null int64
# author_name        16 non-null object
# title              16 non-null object
# hash_tags          7 non-null object
# description        16 non-null object
# file               16 non-null object
# url                16 non-null object
# wifi_tv            16 non-null bool
# comment_id         16 non-null int64
# username           16 non-null object
# message            16 non-null object
# helpful_cnt        16 non-null int64
# not_helpful_cnt    16 non-null int64
# rating             16 non-null int64
# dtypes: bool(1), int64(5), object(9)
# memory usage: 1.9+ KB
#                   date    id author_name  \
# 0  2019-01-01 22:24:24  3132    dougfern
# 1  2019-01-01 22:24:24  3132    dougfern
# 2  2019-01-01 22:24:24  3132    dougfern
#
#                                              title hash_tags  \
# 0  Re-pairing TV/Bluetooth soundbar after shutdown       NaN
# 1  Re-pairing TV/Bluetooth soundbar after shutdown       NaN
# 2  Re-pairing TV/Bluetooth soundbar after shutdown       NaN
#
#                                          description  \
# 0  \nMy new LG 50UK6500AUA TV and SK1 soundbar pa...
# 1  \nMy new LG 50UK6500AUA TV and SK1 soundbar pa...
# 2  \nMy new LG 50UK6500AUA TV and SK1 soundbar pa...
#
#                                                 file  \
# 0  3132-re-pairing-tv-bluetooth-soundbar-after-sh...
# 1  3132-re-pairing-tv-bluetooth-soundbar-after-sh...
# 2  3132-re-pairing-tv-bluetooth-soundbar-after-sh...
#
#                                                  url  wifi_tv  comment_id  \
# 0  https://lgcommunity.us.com/discussion/3132/re-...    False        5115
# 1  https://lgcommunity.us.com/discussion/3132/re-...    False        5546
# 2  https://lgcommunity.us.com/discussion/3132/re-...    False        5542
#
#    username                                            message  helpful_cnt  \
# 0    Snuffy  \n                            I have EXACTLY t...            1
# 1    Snuffy  \n                            Another thing I ...            1
# 2  dougfern  \n                            My experience is...            1
#
#    not_helpful_cnt  rating
# 0                0       1
# 1                0       1
# 2                0       1

# %%
print("Questions out of first ten ones from 2019 that received answers:  ", 
      len(qc10_df['id'].unique()))
print("Total {} answers for 10 questions". format(len(qc10_df)))
# Out:
# Questions out of first ten ones from 2019 that received answers:   10
# Total 16 answers for 10 questions

# %% [markdown]
# #### Answewr 1.4
# - 1.4. For each answer, what is your gut judgement for how likely the answer would have been accepted by
# the thread starter? Why?

# %%
def add2dict(d, key, val):
    if key in d:
        d[key].append(val)
    else:
        d[key]=[val]

# %%
def print_qa(df, file=None):
    """ Print questions with answers, including 
    comment helpfull counts and question / comment similarity
    
        Args:
            df - data frame
            file - file to print to
            
        Rerurns:
            None
    """
    if not file:
        log = sys.stdout
    else:
        log = open(file, 'w') 
        
    qa_dict = {}
    qa_array = df[['description','message', 'helpful_cnt', 'not_helpful_cnt']].values
    for idx, qa in enumerate(qa_array):        
        add2dict(qa_dict, qa[0], (qa[1], qa[2], qa[3]))
    
    q_cnt = 0
    for q in qa_dict:
        print("\n*** Question {} {}".format(q_cnt, q), file=log)
        a_cnt = 0
        for a in qa_dict[q]:
            #print(a[0], a[1], a[2], c_sim)
            print("\n* Answer {}\n{}\n-- Helpful: {}\n-- Not Helpful: {}".format(
                a_cnt,a[0], a[1], a[2]), file=log)
            a_cnt += 1
            
        q_cnt +=1

# %%
print_qa(qc10_df)
# Out:
# *** Question 0
# My new LG 50UK6500AUA TV and SK1 soundbar pair up via Bluetooth as expected. But upon powering down the TV and back on, the TV "sound out" ALWAYS reverts back to "Internal Speaker" even as the soundbar Bluetooth LED sits there blinking, waiting to be invited back in. I must go back through the TV settings to re-pair the two. then everything works fine until the next power-down. Docs say I should only after to pair once! What a pain. Help, please!
#
# * Answer 0
#
#                             I have EXACTLY the same problem on my new 43UK6750PLD TV also with an SK1 soundbar.  To get it to connect to the soundbar when I turn the TV on again, I have to re-select it from the list of paired devices (I don't have to re-pair) but it will not connect automatically.Another way to re-connect is to turn the soundbar on and off with the TV on. Then the TV says something like "The SK1 device is requesting to connect. Do you accept?" (well, words to that effect). And then it works.But I don't want to keep having to do this each time I turn my TV on !
# -- Helpful: 1
# -- Not Helpful: 0
#
# * Answer 1
#
#                             Another thing I found was that after about 30 minutes on Bluetooth the sound was out of sync with the picture. In the end I bought an optical cable and now it works properly.
# -- Helpful: 1
# -- Not Helpful: 0
#
# * Answer 2
#
#                             My experience is exactly like yours. Had LG service here under warranty; they swapped out something but it had no effect. Told me it was the soundbar (yeah, right) so I'll exchange it just to say I did it. Went to Costco to verify I wasn't crazy; their display model worked exactly as you & I expect it to work..."Bluetooth" setting holds even during power cycle.  Sooner or later I'm going to demand a replacement under warranty.
# -- Helpful: 1
# -- Not Helpful: 0
#
# * Answer 3
#
#                             Yes. optical cable came with my SK1 and it works fine. Unfortunately it's not long enough for the headphones I plan to use in my La-Z-Boy across the room! That's why I want the Bluetooth to work as it's supposed to and as I paid for. I'm going to keep pursuing this issue even if -- as you pointed out -- I can work around it with another couple of clicks.
# -- Helpful: 0
# -- Not Helpful: 0
#
# *** Question 1
#                     just set up  60inch 60UK60 4K hdr tv. Picture is not sharp, text is blurry . Where do I go to correct this? This is my first LG and not happy at the moment
#
# * Answer 0
#
# Are you streaming the content via the internet or is the content coming through a set top box?
# -- Helpful: 0
# -- Not Helpful: 0
#
# *** Question 2
#                     I bought my UJ6300 tv about a year ago. Recently I started getting a “Unknown device is doconnected” every few mins. Please help.
#
# * Answer 0
#
# Hi, I'm gathering data to escalate this issue. Can you post your model and firmware version and any notes you think may help isolate the cause. Thanks!
# -- Helpful: 0
# -- Not Helpful: 0
#
# *** Question 3
#                     After only having this tv for 2 months I lost the use of the HDMI port #1 tried different cables no effect switched my PC from the original port 1 to port 2 and it works I plug my ps4 into port 1 and nothing no signal..
#
# * Answer 0
#
# rocky17901 1) Disconnect every device from the HDMI ports on the unit. 2) Press the MUTE button on the remote 3 times and select the option that says AV reset (This will erase any customer settings in the unit). The AV reset will reset the HDMI ports on the TV.3) Reconnect the devices to the HDMI ports on the TV and try again. If the issue doesn't resolve the HDMI port failure, please message LG at https://www.facebook.com/LGUSSupport/
# or https://twitter.com/LGUSSupport for assistance with service.
# -- Helpful: 0
# -- Not Helpful: 0
#
# *** Question 4
#                     I now own:LG 24LJ48440 TV w/ remote AKB 749 153 97NEW! LG 43UK6500AUA TV w/ remote AKB 753 756 04Because of work/home logistics, both products are in the same room, approximately 10-12 ft apart, on opposite walls.Apparently, each remote uses the *same* IR frequency so if I try to turn on the 43" TV with one remote, the signal bounces off the glass and turns on the 24" TV. And vice versa.Called tech support, said I should move the TVs further apart, which is not a viable solution. Also suggested I purchase their 'magic remote' for an additional $50.Opened a case with LG, had to follow-up 3x times after not receiving promised follow-up. Case was escalated and routed to the wrong department, and eventually rerouted back to TV support. Was told that the 'current technology' (remote IR) was limited and there was no solution they could offer (other than moving the products further apart... which, as previously noted, was not a viable option).The tech support agent offered one final solution: I should go out and buy another TV from a competitor.
#
# * Answer 0
#
#                             Hi Mralick,I want to start by apologizing for the frustrating phone experience.  That said, I may be about to frustrate you more.Using the same IR signal for the same product line is an industry standard (that's why universal remotes work).  No matter which brand you use, if you have two of those TVs, the same remote will affect both units.  So, yes, one solution is to use different brands if they must be positioned how they are (maybe you have another brand in another room you could swap?).Also, just to put this to rest: Magic Remotes still use IR for some functions, such as Power and Volume.  So I wouldn't go out and buy a magic remote to solve this.  It could help with interference during other functions, but power will still transmit an IR signal from a Magic Remote.If it's possible to re-arrange the room, you could have the two TVs back-to-back, so the IR reflection doesn't interfere (but watch out for windows/mirrors that may act as reflecting surfaces).Another option is to use the CEC feature that most of our TVs have.  CEC allows the TV's on/off and some other functions to be controlled by another device.  If you have one TV where the main use is an external device, like a gaming system, set-top box, or streaming device, you can enable Simplink on the TV, and it will automatically turn on/off when the other device does (I find turning off isn't always immediate though, my TV generally times out).While this would solve the on/off issue, other functions would likely still interfere, like Volume controls, or accessing the menu.  If the other functions aren't used often, you could put something in the way of the IR receiver on one unit to block the signal completely.  That could also work as a complete solution, if you can find a way to partially obstruct the IR signals on both units, so that you still have an angle from the sitting positions of each, but where the reflected signal won't have line of sight back to the other unit.I know it's frustrating.  I had the same issue a couple of years back, and had to use the CEC with partial obstruction method.I hope something in there helps!  Let me know.Thanks,~Ryan
# -- Helpful: 0
# -- Not Helpful: 0
#
# * Answer 1
#
#                             The frequency has nothing to do with it, it is IR or a wavelength near 940nm or 3.19x10E14 or 319 Terrahertz it could be modulated between 34khz and 56khz but that is also insignificant, it is the digital codes that are transmitted that your devices react to. Having said that, Ryan's answer is good, but there are other factors physical and aesthetic. The reflectivity of the room being most significant, if the walls are painted white it is unlikely you can block the signals effectively. You could try a layer or two of black nylon screen over the emitter on your remote to weaken the signal or find some other material that would absorb some but not all of the energy the remote is transmitting.  You can make a reflector from a piece of aluminum cut from a discarded can and bent at a 45 degree angle placed in front of the tv's receiver and aimed up, down, left or right and then bounce the signal off the ceiling or wall to reach the device, but this might not look appealing and could result in someone being cut. You can try to move one or both TVs left or right to avoid signals bouncing off one's screen to the others receiver. You can try to place materials that either absorb or reflect light in varying places in the room (or remove such items) to help control the path light travels unfortunately both the remotes and the receivers are designed to be wide angle devices which brings us to putting tubes reflective inside and opaque outside in front of both or either remotes or receivers.  Although these solutions may be effective, your wife or clients might find them unsightly and your cat might think they are toys.
# -- Helpful: 0
# -- Not Helpful: 0
#
# *** Question 5
#                     Hi,Can't find any info about connecting this TV to network. Is it possible?No settings in the menus!!!! Want to control over network./Åke
#
# * Answer 0
#
#                             Hi Ake,I don't know very much about our Business TVs, but you can find some documents and a manual at the links below which may help.  You can definitely control it with RS232, but not sure that's what you're looking for.  It has a feature called wake on LAN, so I would think you can at least connect it to the network with Ethernet, but I would check the documentation to find out exactly what the capabilities are.https://www.lg.com/us/support-product/lg-65UV340C#manuals https://www.lg.com/us/business/commercial-display/displays-tvs/commercial/lg-65UV340C#resource I hope that helps.Thanks,~Ryan
# -- Helpful: 0
# -- Not Helpful: 0
#
# *** Question 6
#                     I have an LG 4K HDR Smart TV. Whenever I change picture settings such as brightness, contrast, or color temperature while using one of the apps such as Netflix, the changes are not visible. I have tried all of the different preset picture modes. This problem does not exist when using one of the inputs on the TV, only with apps.
#
# * Answer 0
#
#                             The changes made on the HDMI inputs will not affect the internal apps. It is possible for the settings to be saved for the apps, you only need to changed the picture settings while in Netflix, Amazon, Youtube, etc. Once changed there, the settings will be the same across the internal TV apps.
# -- Helpful: 0
# -- Not Helpful: 0
#
# * Answer 1
#
#                             I have changed the picture settings while in an app and it doesn't change the picture.
# -- Helpful: 0
# -- Not Helpful: 0
#
# * Answer 2
#
# I would recommend ensuring the unit is in home mode and not store mode since store mode will not save the picture settings. Also are we changing the regular picture settings or the picture settings for HDR mode? Lastly, what's the model number to the TV?
# -- Helpful: 0
# -- Not Helpful: 0
#
# *** Question 7
#                     When trying to program universal remote and sync remote and cable box, Bell Fibe was not an option !! Any Canadians able to give assistance if anything can be done? Thank you.
#
# * Answer 0
#
#                             I have the same issue with Magic remote and bell fibe...Cant find a fix!
# -- Helpful: 0
# -- Not Helpful: 0
#
# *** Question 8
# tried everything but still no luck ...i read somewhere the ridiculous " unknown device disconnected / wifi turned off " might be fixed doing a hard reset . my issue got worse ever since i update to latest firmware ...any help would be greatly appreciated . thnx .model : 49sj800
#
# * Answer 0
#
#                             There is a bunch of us who have the same problem as you have. I have done a hard reset and it didn’t help at all. The only way I got rid of the annoying message was to put the tv in store mode. You can do that in settings under general. It allows you to turn off some of the store settings. The picture will be brighter but the message will be gone. Hopefully they will come out with an update that will clear up the mess. Those of us without WiFi will have to connect using Ethernet cable I assume to download the update. For now I have a fire stick to watch Netflix and Prime.
# -- Helpful: 0
# -- Not Helpful: 0
#
# *** Question 9
#                     Hi,  i have a tv model 49uh850v and frequentlly is disconecting from internetnt while i  watch youtube or netflix and then wi fi cannot turn on, any solution?if i unplug tv for a while the problem is fixed but then again the problem appears again, any solution?
#
# * Answer 0
#
#                             Sounds like something is interfering with your WIFI, The TV being too close to the router can cause it, they should be at least 6 Ft apart. Microwave ovens and some Garage Door Openers can also be sources of interference. It's also a good idea to connect the TV and Router by Cable for a multitude of reasons starting with 5 or more times the bandwidth for streaming. Hope this helps.
# -- Helpful: 0
# -- Not Helpful: 0

# %% [markdown]
# ### <font color=blue> My gut judgement of answers</font>

# %% [markdown]
# #### Q0: My new LG 50UK6500AUA TV and SK1 soundbar pair up via Bluetooth as expected. But upon powering down the TV and back on, the TV "sound out" ALWAYS reverts back to "Internal Speaker" even as the soundbar Bluetooth LED sits there blinking, waiting to be invited back in. I must go back through the TV settings to re-pair the two. then everything works fine until the next power-down. Docs say I should only after to pair once! What a pain. Help, please!
#
# * A0:
#                             I have EXACTLY the same problem on my new 43UK6750PLD TV also with an SK1 soundbar.  To get it to connect to the soundbar when I turn the TV on again, I have to re-select it from the list of paired devices (I don't have to re-pair) but it will not connect automatically.Another way to re-connect is to turn the soundbar on and off with the TV on. Then the TV says something like "The SK1 device is requesting to connect. Do you accept?" (well, words to that effect). And then it works.But I don't want to keep having to do this each time I turn my TV on !
#
#  <font color=blue>Not an optimal, temporary solution. Can be accepted when there is no better one. </font>
#
# * A1:
#                             Another thing I found was that after about 30 minutes on Bluetooth the sound was out of sync with the picture. In the end I bought an optical cable and now it works properly.
#
# <font color=blue>Does not answer the question. Can not be accepted. </font>
#
#
# * A2:
#                             My experience is exactly like yours. Had LG service here under warranty; they swapped out something but it had no effect. Told me it was the soundbar (yeah, right) so I'll exchange it just to say I did it. Went to Costco to verify I wasn't crazy; their display model worked exactly as you & I expect it to work..."Bluetooth" setting holds even during power cycle.  Sooner or later I'm going to demand a replacement under warranty.
#
# <font color=blue>Does not answer the question. Can not be accepted. </font>
#
# * A3:
#                             Yes. optical cable came with my SK1 and it works fine. Unfortunately it's not long enough for the headphones I plan to use in my La-Z-Boy across the room! That's why I want the Bluetooth to work as it's supposed to and as I paid for. I'm going to keep pursuing this issue even if -- as you pointed out -- I can work around it with another couple of clicks.
#
# <font color=blue>Additional note from the author of the question. Not an answer the question. Can not be accepted. </font>

# %% [markdown]
# #### Question 2.
# - How many initial posts from 2019 concerned problems connecting the TV to Wi-Fi?
# - Do any of these have answers which potentially could have resolved the problem?
# - If you were to only make a bot for answering Wi-Fi threads, what answer string
# do you think would be the best?
# - Give in code or pseudocode a method which given the initial post determines
# whether to respond to it with this Wi-Fi answer string.
# - How many of the 2019 wifi threads would your answer string be used for and
# what do you think would be the expected acceptance rate of these answers?

# %% [markdown]
# #### Answer 2.1

# %%
# All questions and answers in 2019
qc19_df_ = join(q19_df, c_df).copy()
qc19_df = qc19_df_.sort_values(by='date').copy()
qc19_df.info()
qc19_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1023 entries, 373 to 429
# Data columns (total 15 columns):
# date               1023 non-null object
# id                 1023 non-null int64
# author_name        1023 non-null object
# title              1023 non-null object
# hash_tags          574 non-null object
# description        1023 non-null object
# file               1023 non-null object
# url                1023 non-null object
# wifi_tv            1023 non-null bool
# comment_id         1023 non-null int64
# username           1023 non-null object
# message            1023 non-null object
# helpful_cnt        1023 non-null int64
# not_helpful_cnt    1023 non-null int64
# rating             1023 non-null int64
# dtypes: bool(1), int64(5), object(9)
# memory usage: 120.9+ KB
#                     date    id author_name  \
# 373  2019-01-01 22:24:24  3132    dougfern
# 376  2019-01-01 22:24:24  3132    dougfern
# 375  2019-01-01 22:24:24  3132    dougfern
# 374  2019-01-01 22:24:24  3132    dougfern
# 298  2019-01-02 19:47:27  3144    joanne01
#
#                                                title hash_tags  \
# 373  Re-pairing TV/Bluetooth soundbar after shutdown       NaN
# 376  Re-pairing TV/Bluetooth soundbar after shutdown       NaN
# 375  Re-pairing TV/Bluetooth soundbar after shutdown       NaN
# 374  Re-pairing TV/Bluetooth soundbar after shutdown       NaN
# 298                          Blurry picture and text       NaN
#
#                                            description  \
# 373  \nMy new LG 50UK6500AUA TV and SK1 soundbar pa...
# 376  \nMy new LG 50UK6500AUA TV and SK1 soundbar pa...
# 375  \nMy new LG 50UK6500AUA TV and SK1 soundbar pa...
# 374  \nMy new LG 50UK6500AUA TV and SK1 soundbar pa...
# 298  \n                    just set up  60inch 60UK...
#
#                                                   file  \
# 373  3132-re-pairing-tv-bluetooth-soundbar-after-sh...
# 376  3132-re-pairing-tv-bluetooth-soundbar-after-sh...
# 375  3132-re-pairing-tv-bluetooth-soundbar-after-sh...
# 374  3132-re-pairing-tv-bluetooth-soundbar-after-sh...
# 298                       3144-blurry-picture-and-text
#
#                                                    url  wifi_tv  comment_id  \
# 373  https://lgcommunity.us.com/discussion/3132/re-...    False        5115
# 376  https://lgcommunity.us.com/discussion/3132/re-...    False        5551
# 375  https://lgcommunity.us.com/discussion/3132/re-...    False        5542
# 374  https://lgcommunity.us.com/discussion/3132/re-...    False        5546
# 298  https://lgcommunity.us.com/discussion/3144/blu...    False        5148
#
#       username                                            message  \
# 373     Snuffy  \n                            I have EXACTLY t...
# 376   dougfern  \n                            Yes. optical cab...
# 375   dougfern  \n                            My experience is...
# 374     Snuffy  \n                            Another thing I ...
# 298  JamalofLG  \nAre you streaming the content via the intern...
#
#      helpful_cnt  not_helpful_cnt  rating
# 373            1                0       1
# 376            0                0       0
# 375            1                0       1
# 374            1                0       1
# 298            0                0       0

# %% [markdown]
# #### Initial posts from 2019 concerned problems connecting the TV to Wi-Fi

# %%
wifi_df = qc19_df[qc19_df['wifi_tv'] == 1]
wifi_df.info()
wifi_df.head(3)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 117 entries, 427 to 211
# Data columns (total 15 columns):
# date               117 non-null object
# id                 117 non-null int64
# author_name        117 non-null object
# title              117 non-null object
# hash_tags          42 non-null object
# description        117 non-null object
# file               117 non-null object
# url                117 non-null object
# wifi_tv            117 non-null bool
# comment_id         117 non-null int64
# username           117 non-null object
# message            117 non-null object
# helpful_cnt        117 non-null int64
# not_helpful_cnt    117 non-null int64
# rating             117 non-null int64
# dtypes: bool(1), int64(5), object(9)
# memory usage: 13.8+ KB
#                     date    id author_name  \
# 427  2019-01-06 14:22:27  3188   alireza88
# 170  2019-01-06 19:01:46  3196        theo
# 992  2019-01-10 08:50:37  3248       mdart
#
#                                       title  \
# 427  how to display lg tv Service Menu ????
# 170                    Wi fi not turning on
# 992             ASK LG Why cant I tun on TV
#
#                                              hash_tags  \
# 427  lg49sj800v unknown device disconnected wifi tu...
# 170                                              Wi-Fi
# 992                                 google home ask lg
#
#                                            description  \
# 427  \ntried everything but still no luck ...i read...
# 170  \n                    Hi,  i have a tv model 4...
# 992  \n                    All other command work w...
#
#                                        file  \
# 427  3188-how-to-display-lg-tv-service-menu
# 170               3196-wi-fi-not-turning-on
# 992        3248-ask-lg-why-cant-i-tun-on-tv
#
#                                                    url  wifi_tv  comment_id  \
# 427  https://lgcommunity.us.com/discussion/3188/how...     True        5260
# 170  https://lgcommunity.us.com/discussion/3196/wi-...     True        5298
# 992  https://lgcommunity.us.com/discussion/3248/ask...     True        5519
#
#        username                                            message  \
# 427  silentmeow  \n                            There is a bunch...
# 170   Saarducci  \n                            Sounds like some...
# 992   JamalofLG  \nmdart the reason why is that when the unit i...
#
#      helpful_cnt  not_helpful_cnt  rating
# 427            0                0       0
# 170            0                0       0
# 992            0                0       0

# %%
print("2019 posts, total: {}; WiFi/TV problems: {} ".format( len(qc19_df), len(wifi_df)))
# Out:
# 2019 posts, total: 1023; WiFi/TV problems: 117

# %% [markdown]
# ### Finding answers to potentially resolve the problem in Wi-Fi threads that FAQ bot may use
#
# To find answers we use __Multiple Choice Question Answering__ model trained on two different datasets:
#
# 1. just a few good answers selected manually
# 2. all available answers to WiFI-TV thread
#
# As expected model trained with small dataset has a little choice of answers and performs poorly. While model trained in second case finds much better results. In this last case answer strings that model generates can be used for all WiFi-TV threads

# %% [markdown]
# #### 1. Find WiFi-TV comments taged 'helpful' in 2019 that can be used as WiFi-TV FAQ answers

# %%
wifi_help_df = wifi_df[wifi_df['helpful_cnt'] > 0]#['message']
wifi_help_df[['helpful_cnt', 'comment_id', 'message']]
# Out:
#      helpful_cnt  comment_id  \
# 942            1       12175
# 932            1        6631
# 686            1       10076
# 157            1        9190
# 214            1       10674
# 620            2       12029
# 88             1       13576
#
#                                                message
# 942  \n                            I'm having the s...
# 932  \nVischo, we can try a few things: 1) Go to Se...
# 686  \n                            No problem. I wi...
# 157  \n                            I am having the ...
# 214  \nShazAust_665, If the TV can find and connect...
# 620  \nSheiky__, I would recommend checking to ensu...
# 88   \n                            After updating s...

# %%
wifi_help_df[['comment_id','message']].values
# Out:
# array([[12175,
#         "\n                            I'm having the same problem after the YouTube update from a few days ago. Only on YouTube.OLED55C8PLA.\xa0 It'll be working fine, then just freeze, respond to no input from the remote, and I'll need to turn the TV off for the remote to start working again. It's rendered one of my most used apps on the TV useless. "],
#        [6631,
#         '\nVischo, we can try a few things: 1) Go to Settings, All Settings, General, QuickStart+, turn off, power off the TV & unplug for 1 minute. This would help with freeing up some of the RAM, and eliminate the freezing. 2) While you have updated the internet speed to 1GBPS, we would need to do a speed test. Open the web browser and type in fast.com and it will automatically run a Speed Test. Once completed, advise as to what speed the TV is receiving.  '],
#        [10076,
#         '\n                            No problem. I will have this checked out.                        '],
#        [9190,
#         '\n                            I am having the exact same problem. I have only had the tv about 18 months and the wifi will no longer come on or connect. I thought LG was a good brand but I will NEVER purchase an LG product again. I will be sure to access all of your social \xa0platforms and let people know what horrible products you sell and to stay far away from your "smart" tv\'s!                        '],
#        [10674,
#         '\nShazAust_665, If the TV can find and connect to the 2.4 GHz network,\xa0there would not be a defect with the TV. I would say the TV does not support the 5 GHz network. \xa0                        '],
#        [12029,
#         '\nSheiky__, I would recommend checking to ensure the TV is on HDMI 1. If already confirmed, Switch to another HDMI input and switch the TV to see if the problem continues.                        '],
#        [13576,
#         '\n                            After updating soundbar on the 17th, I have not had any problems with loss of voice audio.\xa0 Hopefully that resolved the issue.\xa0 Thanks for the quick reply and suggestion.                        ']],
#       dtype=object)

# %%
# Drop useless messages: 9190, 10076
wifi_help_df.drop(wifi_help_df[wifi_help_df['comment_id'] == 9190].index, inplace = True)
wifi_help_df.drop(wifi_help_df[wifi_help_df['comment_id'] == 10076].index, inplace = True)
# Out:
# /Users/dk/usr/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py:4117: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
wifi_faq_array = wifi_help_df['message'].values
wifi_faq_array
# Out:
# array(["\n                            I'm having the same problem after the YouTube update from a few days ago. Only on YouTube.OLED55C8PLA.\xa0 It'll be working fine, then just freeze, respond to no input from the remote, and I'll need to turn the TV off for the remote to start working again. It's rendered one of my most used apps on the TV useless. ",
#        '\nVischo, we can try a few things: 1) Go to Settings, All Settings, General, QuickStart+, turn off, power off the TV & unplug for 1 minute. This would help with freeing up some of the RAM, and eliminate the freezing. 2) While you have updated the internet speed to 1GBPS, we would need to do a speed test. Open the web browser and type in fast.com and it will automatically run a Speed Test. Once completed, advise as to what speed the TV is receiving.  ',
#        '\nShazAust_665, If the TV can find and connect to the 2.4 GHz network,\xa0there would not be a defect with the TV. I would say the TV does not support the 5 GHz network. \xa0                        ',
#        '\nSheiky__, I would recommend checking to ensure the TV is on HDMI 1. If already confirmed, Switch to another HDMI input and switch the TV to see if the problem continues.                        ',
#        '\n                            After updating soundbar on the 17th, I have not had any problems with loss of voice audio.\xa0 Hopefully that resolved the issue.\xa0 Thanks for the quick reply and suggestion.                        '],
#       dtype=object)

# %% [markdown]
# #### 2.Create Multiple Choice Question Answering  model

# %% [markdown]
# #### Answer 2.4 Method which given the initial post determines whether to respond to it with this Wi-Fi answer string.

# %%
def model_demo(embedder, corpus, queries):
    """ Demonstrate Multiple Choice Question Answering model
    
        Args:
            embedder - SentenceTransformer to embed text
            corpus - corpus to train model 
            queries - query strings to find best match for
    """

    corpus_embeddings = embedder.encode(corpus)
    query_embeddings = embedder.encode(queries)

        # Find the closest 5 sentences of the corpus for each query sentence based on cosine similarity
    closest_n = 5
    for query, query_embedding in zip(queries, query_embeddings):
        distances = scipy.spatial.distance.cdist([query_embedding], corpus_embeddings, "cosine")[0]

        results = zip(range(len(distances)), distances)
        results = sorted(results, key=lambda x: x[1])

        print("*** Query:\n", query)
        print("\nTop 5 most similar sentences in corpus:")
        print("\n\n======================\n\n")

        for idx, distance in results[0:closest_n]:
            print("(Score: %.4f)" % (1-distance), corpus[idx].strip())
            print("\n\n======================\n\n")

# %%
# Query sentences:
queries = [""" Hi,\xa0 i have a tv model 49uh850v and frequentlly is disconecting 
from internetnt while i\xa0 watch youtube or netflix and then wi fi cannot turn on, 
any solution?if i unplug tv for a while the problem is fixed but then again the problem 
appears again, any solution?
"""]

# %% [markdown]
# #### 3.a. Train and run model on comments taged 'helpful' in 2019

# %%
# %%time
# Create Model
embedder = SentenceTransformer('bert-base-nli-mean-tokens')

# Find best matches
corpus_wifi_faq = wifi_faq_array
model_demo(embedder, corpus_wifi_faq, queries)
# Out:
# *** Query:
#   Hi,  i have a tv model 49uh850v and frequentlly is disconecting
# from internetnt while i  watch youtube or netflix and then wi fi cannot turn on,
# any solution?if i unplug tv for a while the problem is fixed but then again the problem
# appears again, any solution?
#
#
# Top 5 most similar sentences in corpus:
#
#
# ======================
#
#
# (Score: 0.8621) I'm having the same problem after the YouTube update from a few days ago. Only on YouTube.OLED55C8PLA.  It'll be working fine, then just freeze, respond to no input from the remote, and I'll need to turn the TV off for the remote to start working again. It's rendered one of my most used apps on the TV useless.
#
#
# ======================
#
#
# (Score: 0.6964) ShazAust_665, If the TV can find and connect to the 2.4 GHz network, there would not be a defect with the TV. I would say the TV does not support the 5 GHz network.
#
#
# ======================
#
#
# (Score: 0.6225) Sheiky__, I would recommend checking to ensure the TV is on HDMI 1. If already confirmed, Switch to another HDMI input and switch the TV to see if the problem continues.
#
#
# ======================
#
#
# (Score: 0.5931) Vischo, we can try a few things: 1) Go to Settings, All Settings, General, QuickStart+, turn off, power off the TV & unplug for 1 minute. This would help with freeing up some of the RAM, and eliminate the freezing. 2) While you have updated the internet speed to 1GBPS, we would need to do a speed test. Open the web browser and type in fast.com and it will automatically run a Speed Test. Once completed, advise as to what speed the TV is receiving.
#
#
# ======================
#
#
# (Score: 0.3731) After updating soundbar on the 17th, I have not had any problems with loss of voice audio.  Hopefully that resolved the issue.  Thanks for the quick reply and suggestion.
#
#
# ======================
#
#
# CPU times: user 5.21 s, sys: 507 ms, total: 5.72 s
# Wall time: 3.13 s

# %% [markdown]
# #### 3.b. Train and run model on *all* WiFi-TV comments from 2019

# %%
# %%time
# Create Model
embedder = SentenceTransformer('bert-base-nli-mean-tokens')

# Find best matches
corpus_wifi_all = wifi_df['message'].values
model_demo(embedder, corpus_wifi_all, queries)
# Out:
# *** Query:
#   Hi,  i have a tv model 49uh850v and frequentlly is disconecting
# from internetnt while i  watch youtube or netflix and then wi fi cannot turn on,
# any solution?if i unplug tv for a while the problem is fixed but then again the problem
# appears again, any solution?
#
#
# Top 5 most similar sentences in corpus:
#
#
# ======================
#
#
# (Score: 0.8791) My 65” B7 and have the same problem. My tv randomly becomes unresponsive and slow with the remote. Buttons on tv is fast. Then today I tried to kill YouTube app (longe press back) and everything become smooth again. Something is wrong with the YouTube app and it only getting worse.
#
#
# ======================
#
#
# (Score: 0.8621) I'm having the same problem after the YouTube update from a few days ago. Only on YouTube.OLED55C8PLA.  It'll be working fine, then just freeze, respond to no input from the remote, and I'll need to turn the TV off for the remote to start working again. It's rendered one of my most used apps on the TV useless.
#
#
# ======================
#
#
# (Score: 0.8236) There is a bunch of us who have the same problem as you have. I have done a hard reset and it didn’t help at all. The only way I got rid of the annoying message was to put the tv in store mode. You can do that in settings under general. It allows you to turn off some of the store settings. The picture will be brighter but the message will be gone. Hopefully they will come out with an update that will clear up the mess. Those of us without WiFi will have to connect using Ethernet cable I assume to download the update. For now I have a fire stick to watch Netflix and Prime.
#
#
# ======================
#
#
# (Score: 0.8113) I am having the exact same problem. I have only had the tv about 18 months and the wifi will no longer come on or connect. I thought LG was a good brand but I will NEVER purchase an LG product again. I will be sure to access all of your social  platforms and let people know what horrible products you sell and to stay far away from your "smart" tv's!
#
#
# ======================
#
#
# (Score: 0.7938) Having the same problem with my SMP9000PUA 4k ThinQ which is new since a month ago. Ours connects immediately to Netflix/Youtube/Prime, etc. but the TV won't immediately pick up any of the LG channels. Would love to know if you find a fix - good luck.
#
#
# ======================
#
#
# CPU times: user 38.5 s, sys: 1.77 s, total: 40.2 s
# Wall time: 11.6 s

# %% [markdown]
# #### Function to get best answer and its score

# %%
def best_answer(embedder, query, corpus, corpus_embeddings):
    """ Find the closest sentence of the corpus 
    for a query sentence based on cosine similarity and 
    return the best sentence with its score
    
        Args:
            embedder - SentenceTransformer to embed text        
            query - query strings
            query_embeddings - query embeddings
            corpus - corpus used to train model
            corpus_embeddings - corpus embedding
            
        Returns:
            (1- distance, sentence) - best score and best sentence 
    """ 
    query_embedding = embedder.encode(query)[0]
    distances = scipy.spatial.distance.cdist([query_embedding], corpus_embeddings, "cosine")[0]
    results = zip(range(len(distances)), distances)
    results = sorted(results, key=lambda x: x[1])

    idx = results[0][0]
    distance = results[0][1]
    best_result = ( "%.4f"%(1-distance), corpus[idx].strip())
    
    return best_result

# %% [markdown]
# #### Find best answers with model trained on *all* WiFi-TV comments from 2019

# %%
# %%time
# Create Model
embedder = SentenceTransformer('bert-base-nli-mean-tokens')
corpus_wifi_all_embeddings = embedder.encode(corpus_wifi_all)
# Out:
# CPU times: user 39.3 s, sys: 1.82 s, total: 41.1 s
# Wall time: 11.9 s

# %%
def print_best_answer(embedder, query, corpus, corpus_embeddings):
    print("***Query:\n", query, "\n*** Best Answer:\n",
      best_answer(embedder, query, corpus, corpus_embeddings))

# %%
# %%time
x1 = [""" Hi,\xa0 i have a tv model 49uh850v and frequentlly is disconecting 
from internetnt while i\xa0 watch youtube or netflix and then wi fi cannot turn on, 
any solution?if i unplug tv for a while the problem is fixed but then again the problem 
appears again, any solution?
"""]
x2 = ["""\ntried everything but still no luck ...i read somewhere the ridiculous " 
unknown device disconnected / wifi turned off " might be fixed doing a hard reset .\xa0my 
issue got worse ever since i update to latest firmware ...
any help would be greatly appreciated .\xa0thnx .model : 49sj800\xa0                """]

queries = [x1,x2]
for x in queries:
    print_best_answer(embedder, x, corpus_wifi_all, corpus_wifi_all_embeddings)
# Out:
# ***Query:
#  [' Hi,\xa0 i have a tv model 49uh850v and frequentlly is disconecting \nfrom internetnt while i\xa0 watch youtube or netflix and then wi fi cannot turn on, \nany solution?if i unplug tv for a while the problem is fixed but then again the problem \nappears again, any solution?\n']
# *** Best Answer:
#  ('0.8791', 'My 65” B7 and have the same problem. My tv randomly becomes unresponsive and slow with the remote. Buttons on tv is fast. Then today I tried to kill YouTube app (longe press back) and everything become smooth again. Something is wrong with the YouTube app and it only getting worse.')
# ***Query:
#  ['\ntried everything but still no luck ...i read somewhere the ridiculous " \nunknown device disconnected / wifi turned off " might be fixed doing a hard reset .\xa0my \nissue got worse ever since i update to latest firmware ...\nany help would be greatly appreciated .\xa0thnx .model : 49sj800\xa0                ']
# *** Best Answer:
#  ('0.8319', 'There is a bunch of us who have the same problem as you have. I have done a hard reset and it didn’t help at all. The only way I got rid of the annoying message was to put the tv in store mode. You can do that in settings under general. It allows you to turn off some of the store settings. The picture will be brighter but the message will be gone. Hopefully they will come out with an update that will clear up the mess. Those of us without WiFi will have to connect using Ethernet cable I assume to download the update. For now I have a fire stick to watch Netflix and Prime.')
# CPU times: user 994 ms, sys: 30.7 ms, total: 1.02 s
# Wall time: 257 ms

# %% [markdown]
# ### Question 3 and 4
# - Analyze the forum and come up with the best five answer strings for the bot.
# - Produce and share a CSV which contains a row for each thread started in 2019
# with the thread URL, the first post, and which of the five answer
# strings the bot should respond with, if any.
# - Provide an estimate for how many of those responses would have been
# accepted respectively rejected.
#
# - Suppose that we could do the work of Question 3 but for up to 50 answer strings. Estimate the number of accepted and rejected proposed answers for 2019 threads for the best one answer string, for the best two, etc, up to the best 50 answer strings.

# %% [markdown]
# ### Find best answers for all threads in 2019

# %% [markdown]
# #### Answer 3.2:  CSV which contains a row for each thread started in 2019 with the thread URL, the first post, and which of the five answer strings the bot should respond with, if any.

# %%
# All 2019 questions with comments
df = join(q19_df, c_df).copy()
df.info()
df.head(3)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1023 entries, 0 to 1022
# Data columns (total 15 columns):
# date               1023 non-null object
# id                 1023 non-null int64
# author_name        1023 non-null object
# title              1023 non-null object
# hash_tags          574 non-null object
# description        1023 non-null object
# file               1023 non-null object
# url                1023 non-null object
# wifi_tv            1023 non-null bool
# comment_id         1023 non-null int64
# username           1023 non-null object
# message            1023 non-null object
# helpful_cnt        1023 non-null int64
# not_helpful_cnt    1023 non-null int64
# rating             1023 non-null int64
# dtypes: bool(1), int64(5), object(9)
# memory usage: 120.9+ KB
#                   date    id author_name  \
# 0  2019-08-19 21:00:57  5745    jmcl1960
# 1  2019-08-19 21:00:57  5745    jmcl1960
# 2  2019-08-19 21:00:57  5745    jmcl1960
#
#                                                title hash_tags  \
# 0  LG 55UK6200PUA Sound Mode is "Deactivated, can...       NaN
# 1  LG 55UK6200PUA Sound Mode is "Deactivated, can...       NaN
# 2  LG 55UK6200PUA Sound Mode is "Deactivated, can...       NaN
#
#                                          description  \
# 0  \nMy LG 55UK6200PUA Sound Mode is "Deactivated...
# 1  \nMy LG 55UK6200PUA Sound Mode is "Deactivated...
# 2  \nMy LG 55UK6200PUA Sound Mode is "Deactivated...
#
#                                                 file  \
# 0  5745-lg-55uk6200pua-sound-mode-is-deactivated-...
# 1  5745-lg-55uk6200pua-sound-mode-is-deactivated-...
# 2  5745-lg-55uk6200pua-sound-mode-is-deactivated-...
#
#                                                  url  wifi_tv  comment_id  \
# 0  https://lgcommunity.us.com/discussion/5745/lg-...    False       11591
# 1  https://lgcommunity.us.com/discussion/5745/lg-...    False       11606
# 2  https://lgcommunity.us.com/discussion/5745/lg-...    False       11647
#
#     username                                            message  helpful_cnt  \
# 0   jmcl1960  \n                            It's on Cinema m...            0
# 1  JamalofLG  \njmcl1960, Are you using a sound bar or the i...            0
# 2   jmcl1960  \n                            I am using inter...            0
#
#    not_helpful_cnt  rating
# 0                0       0
# 1                0       0
# 2                0       0

# %%
df.columns
# Out:
# Index(['date', 'id', 'author_name', 'title', 'hash_tags', 'description',
#        'file', 'url', 'wifi_tv', 'comment_id', 'username', 'message',
#        'helpful_cnt', 'not_helpful_cnt', 'rating'],
#       dtype='object')

# %%
drop_cols = ['author_name','comment_id','username']
df = df.drop(drop_cols, axis=1)

# %%
# Data frame with row for each thread started in 2019 
# that have thread URL and the first post
df['date'] = pd.to_datetime(df['date']) 
q19c_df = df.loc[df.groupby('id')['date'].idxmin()].copy()
q19c_df.info()
q19c_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 466 entries, 373 to 429
# Data columns (total 12 columns):
# date               466 non-null datetime64[ns]
# id                 466 non-null int64
# title              466 non-null object
# hash_tags          245 non-null object
# description        466 non-null object
# file               466 non-null object
# url                466 non-null object
# wifi_tv            466 non-null bool
# message            466 non-null object
# helpful_cnt        466 non-null int64
# not_helpful_cnt    466 non-null int64
# rating             466 non-null int64
# dtypes: bool(1), datetime64[ns](1), int64(4), object(6)
# memory usage: 44.1+ KB
#                    date    id  \
# 373 2019-01-01 22:24:24  3132
# 298 2019-01-02 19:47:27  3144
# 796 2019-01-03 07:38:20  3155
# 711 2019-01-03 08:00:11  3156
# 147 2019-01-03 17:43:35  3161
#
#                                                  title  \
# 373    Re-pairing TV/Bluetooth soundbar after shutdown
# 298                            Blurry picture and text
# 796                     Unknown Device Is Disconnected
# 711                          49UK6200PUA HDMI Problems
# 147  Two different products, two different remotes,...
#
#                                  hash_tags  \
# 373                                    NaN
# 298                                    NaN
# 796                                    NaN
# 711                                    NaN
# 147  Remote Infrared Remote malfunctioning
#
#                                            description  \
# 373  \nMy new LG 50UK6500AUA TV and SK1 soundbar pa...
# 298  \n                    just set up  60inch 60UK...
# 796  \n                    I bought my UJ6300 tv ab...
# 711  \n                    After only having this t...
# 147  \n                    I now own:LG 24LJ48440 T...
#
#                                                   file  \
# 373  3132-re-pairing-tv-bluetooth-soundbar-after-sh...
# 298                       3144-blurry-picture-and-text
# 796                3155-unknown-device-is-disconnected
# 711                     3156-49uk6200pua-hdmi-problems
# 147  3161-two-different-products-two-different-remo...
#
#                                                    url  wifi_tv  \
# 373  https://lgcommunity.us.com/discussion/3132/re-...    False
# 298  https://lgcommunity.us.com/discussion/3144/blu...    False
# 796  https://lgcommunity.us.com/discussion/3155/unk...    False
# 711  https://lgcommunity.us.com/discussion/3156/49u...    False
# 147  https://lgcommunity.us.com/discussion/3161/two...    False
#
#                                                message  helpful_cnt  \
# 373  \n                            I have EXACTLY t...            1
# 298  \nAre you streaming the content via the intern...            0
# 796  \nHi, I'm gathering data to escalate this issu...            0
# 711  \nrocky17901 1) Disconnect every device from t...            0
# 147  \n                            Hi Mralick,I wan...            0
#
#      not_helpful_cnt  rating
# 373                0       1
# 298                0       0
# 796                0       0
# 711                0       0
# 147                0       0

# %%
# c19_df - all comments in 2019
mask_c = (c_df['date'] > '2018-12-31') & (c_df['date'] <= '2019-12-31')
c19_df = c_df.loc[mask_c].copy()
c19_df.info()
c19_df.head(3)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1079 entries, 7 to 1848
# Data columns (total 10 columns):
# date               1079 non-null object
# question_id        1079 non-null int64
# hash_tags          582 non-null object
# comment_id         1079 non-null int64
# username           1079 non-null object
# message            1079 non-null object
# helpful_cnt        1079 non-null int64
# not_helpful_cnt    1079 non-null int64
# rating             1079 non-null int64
# file               1079 non-null object
# dtypes: int64(5), object(5)
# memory usage: 92.7+ KB
#                   date  question_id hash_tags  comment_id   username  \
# 7  2019-08-19 21:04:08         5745       NaN       11591   jmcl1960
# 8  2019-08-20 13:47:18         5745       NaN       11606  JamalofLG
# 9  2019-08-21 14:06:48         5745       NaN       11647   jmcl1960
#
#                                              message  helpful_cnt  \
# 7  \n                            It's on Cinema m...            0
# 8  \njmcl1960, Are you using a sound bar or the i...            0
# 9  \n                            I am using inter...            0
#
#    not_helpful_cnt  rating                                               file
# 7                0       0  5745-lg-55uk6200pua-sound-mode-is-deactivated-...
# 8                0       0  5745-lg-55uk6200pua-sound-mode-is-deactivated-...
# 9                0       0  5745-lg-55uk6200pua-sound-mode-is-deactivated-...

# %% [markdown]
# #### Answer to Question 4: up to 50 best answer strings.

# %%
# Create corpus from all comments (answers) in the thread, from all years
#corpus_all = c_df['message'].values #1849 messages

# Create corpus from all comments (answers) in 2019
#corpus_all = c19_df['message'].values #1079 messages

# Create corpus from all _helpful_ comments (answers) in 2019
corpus_all = c19_df[c19_df['helpful_cnt'] > 0]['message'].values

len(corpus_all)
# Out:
# 83

# %%
# %%time
# Create Model from all comments
embedder = SentenceTransformer('bert-base-nli-mean-tokens')
corpus_all_embeddings = embedder.encode(corpus_all)
# Out:
# CPU times: user 37.4 s, sys: 1.81 s, total: 39.2 s
# Wall time: 11.5 s

# %% [markdown]
# #### CSV which contains a row for each thread started in 2019 with the thread URL, the first post, and which of the five answer strings the bot should respond with

# %%
# %%time

# Add best answer with score to 2019 questions data frame 

q19c_df[['best_score', 'best_answer']] = q19c_df.apply(lambda x: 
                                                       pd.Series(
                                                           best_answer(
                                                               embedder, 
                                                               [x['description']], 
                                                               corpus_all, 
                                                               corpus_all_embeddings)
                                                       ), axis=1)
# Out:
# CPU times: user 4min 1s, sys: 4.62 s, total: 4min 5s
# Wall time: 1min 1s

# %%
q19c_df.info()
q19c_df.head(3)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 466 entries, 373 to 429
# Data columns (total 14 columns):
# date               466 non-null datetime64[ns]
# id                 466 non-null int64
# title              466 non-null object
# hash_tags          245 non-null object
# description        466 non-null object
# file               466 non-null object
# url                466 non-null object
# wifi_tv            466 non-null bool
# message            466 non-null object
# helpful_cnt        466 non-null int64
# not_helpful_cnt    466 non-null int64
# rating             466 non-null int64
# best_score         466 non-null object
# best_answer        466 non-null object
# dtypes: bool(1), datetime64[ns](1), int64(4), object(8)
# memory usage: 51.4+ KB
#                    date    id  \
# 373 2019-01-01 22:24:24  3132
# 298 2019-01-02 19:47:27  3144
# 796 2019-01-03 07:38:20  3155
#
#                                                title hash_tags  \
# 373  Re-pairing TV/Bluetooth soundbar after shutdown       NaN
# 298                          Blurry picture and text       NaN
# 796                   Unknown Device Is Disconnected       NaN
#
#                                            description  \
# 373  \nMy new LG 50UK6500AUA TV and SK1 soundbar pa...
# 298  \n                    just set up  60inch 60UK...
# 796  \n                    I bought my UJ6300 tv ab...
#
#                                                   file  \
# 373  3132-re-pairing-tv-bluetooth-soundbar-after-sh...
# 298                       3144-blurry-picture-and-text
# 796                3155-unknown-device-is-disconnected
#
#                                                    url  wifi_tv  \
# 373  https://lgcommunity.us.com/discussion/3132/re-...    False
# 298  https://lgcommunity.us.com/discussion/3144/blu...    False
# 796  https://lgcommunity.us.com/discussion/3155/unk...    False
#
#                                                message  helpful_cnt  \
# 373  \n                            I have EXACTLY t...            1
# 298  \nAre you streaming the content via the intern...            0
# 796  \nHi, I'm gathering data to escalate this issu...            0
#
#      not_helpful_cnt  rating best_score  \
# 373                0       1     0.8698
# 298                0       0     0.7711
# 796                0       0     0.7402
#
#                                            best_answer
# 373  I have EXACTLY the same problem on my new 43UK...
# 298  I have the LG 65UJ6300 which my wife bought on...
# 796  So we are having the same issue.  We bought ou...

# %% [markdown]
# #### Write best answers to csv file

# %%
q19c_df.to_csv(BEST_ANSWERS_CSV)

# %% [markdown]
# #### Explore some best answers in 2019 thread

# %%
# Select questions that have 'not helpful' tags
not_helpful_df = q19c_df[q19c_df['not_helpful_cnt'] != 0]
not_helpful_df.info()
not_helpful_df.head(3)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 30 entries, 319 to 863
# Data columns (total 14 columns):
# date               30 non-null datetime64[ns]
# id                 30 non-null int64
# title              30 non-null object
# hash_tags          19 non-null object
# description        30 non-null object
# file               30 non-null object
# url                30 non-null object
# wifi_tv            30 non-null bool
# message            30 non-null object
# helpful_cnt        30 non-null int64
# not_helpful_cnt    30 non-null int64
# rating             30 non-null int64
# best_score         30 non-null object
# best_answer        30 non-null object
# dtypes: bool(1), datetime64[ns](1), int64(4), object(8)
# memory usage: 3.3+ KB
#                    date    id                                         title  \
# 319 2019-03-01 17:09:38  3730  HDMI Input No Longer Works on my 55UK6300PUE
# 682 2019-05-30 01:37:32  4479                 LG 55SM8600PUA Netflix issues
# 659 2019-06-02 16:56:06  4520  55UK6090PUA randomly starts my BPM25 Blu-Ray
#
#                                         hash_tags  \
# 319                         HDMI Problem TV INPUT
# 682                                           NaN
# 659  ATMOS ARC SIMPLINK LG 55UK6090 BPM25 Blu Ray
#
#                                            description  \
# 319  \n                    The HDMI input #2 on my ...
# 682  \n                    Hello, I recently purcha...
# 659  \n                    We recently bought a 55U...
#
#                                                   file  \
# 319  3730-hdmi-input-no-longer-works-on-my-55uk6300pue
# 682                 4479-lg-55sm8600pua-netflix-issues
# 659  4520-55uk6090pua-randomly-starts-my-bpm25-blu-ray
#
#                                                    url  wifi_tv  \
# 319  https://lgcommunity.us.com/discussion/3730/hdm...    False
# 682  https://lgcommunity.us.com/discussion/4479/lg-...     True
# 659  https://lgcommunity.us.com/discussion/4520/55u...    False
#
#                                                message  helpful_cnt  \
# 319  \nproblemunsolved, two things you can try as a...            0
# 682  \nTrahurst, thanks for the info. Have you noti...            0
# 659  \nDWNKS49, the SIMPLINK settings is causing th...            0
#
#      not_helpful_cnt  rating best_score  \
# 319                2      -2     0.8634
# 682                1      -1     0.8576
# 659                1      -1     0.8239
#
#                                            best_answer
# 319  I've Google searched the internet for this pro...
# 682  I'm having the same problem after the YouTube ...
# 659  I have EXACTLY the same problem on my new 43UK...

# %%
# Select questions that have 'not helpful' tags
#queries = not_helpful_df['description'].head(5).values
#queries = not_helpful_df['description'].sample(5).values

# %%
# Randomly select any 2019 questions 
queries = q19c_df['description'].sample(5).values
for x in queries:
    print_best_answer(embedder, [x], corpus_all, corpus_all_embeddings)
# Out:
# ***Query:
#  ["\n                    I literally just opened and set up my new LG UHD TV AI ThinQ 43UK63, and the top of the TV has a thin purple line of light across it and the physical top of the TV is curved upward in this same area. I cannot find anywhere online that says anything about this, and it makes me believe I have gotten a damaged product. I don't know if this is a setting that needs to be adjusted or if it a defect. PLEASE HELP!                "]
# *** Best Answer:
#  ('0.7955', 'I have EXACTLY the same problem on my new\xa043UK6750PLD TV also with an SK1 soundbar.\xa0 To get it to connect to the soundbar when I turn the TV on again, I have to re-select it from the list of paired devices (I don\'t have to re-pair) but it will not connect automatically.Another way to re-connect is to turn the soundbar on and off with the TV on. Then the TV says something like "The SK1 device is requesting to connect. Do you accept?" (well, words to that effect). And then it works.But I don\'t want to keep having to do this each time I turn my TV on !')
# ***Query:
#  ["\n                    Setting up my new 50UM7300AUE TV last night, came with the Magic Remote ( I HATE) and it didn't work on the cable box. Reset to factory settings and now the TV is stuck on the language selection screen. Guide works, everything else works EXCEPT I get no picture except the language selection screen. Can anyone help me?                "]
# *** Best Answer:
#  ('0.8507', "I'm having the same problem after the YouTube update from a few days ago. Only on YouTube.OLED55C8PLA.\xa0 It'll be working fine, then just freeze, respond to no input from the remote, and I'll need to turn the TV off for the remote to start working again. It's rendered one of my most used apps on the TV useless.")
# ***Query:
#  ['\n                    When is LG coming out with a software update and app to be able to watch Apple TV+ like they did for Disney+??                ']
# *** Best Answer:
#  ('0.7985', 'Please update your smart tv apps, so I don’t have to replace my new LG TVs for a Samsung smart tv just to get the Spectrum app! Thanks')
# ***Query:
#  ["\nOver the past few days, we have been having WiFi connection trouble. We have a NetGear 5GHz router and the TV has been connected to it for over a year and we haven't had a problem. Recently however, the TV dropped WiFi connection frequently and would not connect in a steady manner. We looked up forums and tried things like, turning off the QuickStart feature, changing location settings, switching to the 2Hz line and doing power cycles on both the router and TV, but none has worked so far. I have also checked if the WebOS was up to date and it is. You can't predict when the TV will connect or if how long it will stay connected. It has gotten worse today and it has not connected to WiFi yet.  "]
# *** Best Answer:
#  ('0.9315', 'My TV has the same problem, at the beginning there was only a message that it had disconnected from the network and it had reconnected, this happened once a week and it was only those two messages, in November the messages from an unknown device were I began to appear sporadically, in December the messages come out every 10 minutes, my wifi is disconnected and I can not activate it, I connect by cable this gives me access to the internet but in minutes I lose it again which makes me use Netflix, Amazon Video and YouTube are practically impossible. In addition to this the remote control stops working, the cursor does not appear on the screen and the response of the buttons has a lag that makes it impossible to use it and a couple of weeks ago the TV restarts after the messages go out without stopping for several seconds. I would believe that this is a hardware problem as this affects the wireless communication of the remote control, so I think it is a problem with the wireless card, my TV is still under warranty but I want to know if it is a problem of software also since I see that several indicate that the problem was presented after the firmware update.TV: 55SJ8000Software Version:\xa0 05.80.15Greetings from Peru!')
# ***Query:
#  ['\n                    2019 TV 82UM8070PUA does not recognize Audio DTS 5.1 44.1 khz .WAV files. Older LG TV can do it.. WebOS upated to 04.70.04.Anyone knows about it? ']
# *** Best Answer:
#  ('0.7753', 'SG82, I would not believe this feature to be coming to the 55UH7700 since it is an older model. It would have been added to the TV previously when the UK6500 was released.')
